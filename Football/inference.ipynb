# %%
import cv2 as cv
from ultralytics import YOLO

# %%
model_path = "../models/yolo11x.pt"
model = YOLO(model_path)
model.to('cuda')
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(96, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(96, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
results = model.predict('../Resource/Videos/08fd33_4.mp4', save=True)
print(results[0])
for box in results[0].boxes:
    print(box)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) d:\mr_document\Git Projects\YOLO-Projects\Football\..\Resource\Videos\08fd33_4.mp4: 384x640 22 persons, 1 sports ball, 73.2ms
# video 1/1 (frame 2/750) d:\mr_document\Git Projects\YOLO-Projects\Football\..\Resource\Videos\08fd33_4.mp4: 384x640 22 persons, 1 sports ball, 25.6ms
# video 1/1 (frame 3/750) d:\mr_document\Git Projects\YOLO-Projects\Football\..\Resource\Videos\08fd33_4.mp4: 384x640 21 persons, 27.1ms
# ...

# %%
dataset_path = '../Datasets/football-players-detection.v12i.yolov11/data.yaml'
model_path = "../models/yolo11x.pt"

# %%
# !yolo task=detect mode=train model="../models/yolo11x.pt" data='../Datasets/football-players-detection.v12i.yolov11/data.yaml' epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.86 🚀 Python-3.10.9 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4060, 8187MiB)
#   0%|          | 0.00/755k [00:00<?, ?B/s]
#  68%|██████▊   | 512k/755k [00:00<00:00, 4.75MB/s]
# 100%|██████████| 755k/755k [00:00<00:00, 6.26MB/s]
#
#   0%|          | 0.00/5.35M [00:00<?, ?B/s]
#   7%|▋         | 384k/5.35M [00:00<00:01, 2.91MB/s]
#  16%|█▋        | 896k/5.35M [00:00<00:01, 3.75MB/s]
#  23%|██▎       | 1.25M/5.35M [00:00<00:01, 3.81MB/s]
#  33%|███▎      | 1.75M/5.35M [00:00<00:00, 4.30MB/s]
#  42%|████▏     | 2.25M/5.35M [00:00<00:00, 4.01MB/s]
#  51%|█████▏    | 2.75M/5.35M [00:00<00:00, 3.99MB/s]
#  65%|██████▌   | 3.50M/5.35M [00:00<00:00, 4.94MB/s]
#  84%|████████▍ | 4.50M/5.35M [00:00<00:00, 6.29MB/s]
# 100%|██████████| 5.35M/5.35M [00:01<00:00, 5.44MB/s]
#
# train: Scanning D:\mr_document\Git Projects\YOLO-Projects\Datasets\football-players-detection.v12i.yolov11\train\labels...:   0%|          | 0/298 [00:00<?, ?it/s]
# ...

# %%
# Out:
# cpu
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#       3 print(device)
# ----> 4 model = model.to(device)
#
# NameError: name 'model' is not defined
